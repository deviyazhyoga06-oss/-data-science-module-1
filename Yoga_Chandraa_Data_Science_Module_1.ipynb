# %% [markdown]
# <a href="https://colab.research.google.com/github/deviyazhyoga06-oss/-data-science-module-1/blob/main/Yoga_Chandraa_Data_Science_Module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, I am Yoga Chandraa")
print("Welcome to my Data Science Internship - Module 1")
# Out:
# Hello, I am Yoga Chandraa
# Welcome to my Data Science Internship - Module 1

# %%
name = "Yoga Chandraa"
age = 18
course = "B.Tech Artificial Intelligence and Data Science"

print("Name:", name)
print("Age:", age)
print("Course:", course)o
# Out:
# Name: Yoga Chandraa
# Age: 18
# Course: B.Tech Artificial Intelligence and Data Science

# %%
name = "Yoga"
age = 18
cgpa = 9.41
student = True
o
print(type(name))
print(type(age))
print(type(cgpa))
print(type(student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
skills = ["Python", "Data Science", "Machine Learning", "Power BI"]

print(skills)
print("First skill:", skills[0])
# Out:
# ['Python', 'Data Science', 'Machine Learning', 'Power BI']
# First skill: Python

# %%
student = {
    "name": "Yoga Chandraa",
    "course": "B.Tech AIDS",
    "year": 3
}

print(student)
print("Name:", student["name"])
print("Course:", student["course"])
print("Year:", student["year"])
# Out:
# {'name': 'Yoga Chandraa', 'course': 'B.Tech AIDS', 'year': 3}
# Name: Yoga Chandraa
# Course: B.Tech AIDS
# Year: 3

# %%
marks = 75

if marks >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
skills = ["Python", "Data Science", "Machine Learning", "Power BI"]

for skill in skills:
    print(skill)
# Out:
# Python
# Data Science
# Machine Learning
# Power BI

# %%
def greet(name):
    print("Hello", name)
    print("Welcome to Data Science")

greet("Yoga")
# Out:
# Hello Yoga
# Welcome to Data Science

# %%
file = open("sample.txt", "w")
file.write("This is my Data Science internship practice.")
file.close()

print("File created successfully.")
# Out:
# File created successfully.

# %%
file = open("sample.txt", "r")
content = file.read()
file.close()

print(content)
# Out:
# This is my Data Science internship practice.

# %%
marks = [75, 80, 65, 90, 85]

total = sum(marks)
average = total / len(marks)

print("Marks:", marks)
print("Total:", total)
print("Average:", average)
# Out:
# Marks: [75, 80, 65, 90, 85]
# Total: 395
# Average: 79.0

# %%
# Data Science Introduction
#
# Data Science is the process of collecting, analyzing,
# and interpreting data to find useful information
# and support decision-making.
#
# Applications of Data Science:
# 1. Customer analysis
# 2. Sales prediction
# 3. Fraud detection
# 4. Recommendation systems
# 5. Healthcare analysis
